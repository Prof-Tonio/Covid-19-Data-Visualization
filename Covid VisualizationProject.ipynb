# %% [markdown]
# # Dynamic Chart - Project

# %% [markdown]
# ## 来吧，这个你念念不忘的图
# 制作一份横向动态柱状图，显示2021-01-01以后，美国确诊总人数前十名的州随着时间的变化
# （District of Columbia 可以视作一个州）
# https://github.com/CSSEGISandData/COVID-19
#
# 数据来自：time_series_covid19_confirmed_US.csv

# %% [markdown]
# ### Hint
# 1. .set_index()可以把column转化为row index
# 2. pyechart无法对barplot排序，创建的时候先放进横向barplot中的数据会被排在最下面
# 3. tl.add_schema(play_interval= ,is_loop_play= ) 可以调整Timeline动画的速度和是否循环播放
# 4. 可以规定x轴的取值范围以保证动态图的美观
#
# 画图前数据的样子：
# ![image.png](attachment:image.png)
#
# 柱状图的样子：
# ![image-2.png](attachment:image-2.png)

# %%
#参考code

#https://gallery.pyecharts.org/#/Timeline/timeline_bar_reversal
from pyecharts import options as opts
from pyecharts.charts import Bar, Timeline
from pyecharts.faker import Faker

tl = Timeline()
for i in range(2015, 2020):
    bar = (
        Bar()
        .add_xaxis(Faker.choose())
        .add_yaxis("商家A", Faker.values(), label_opts=opts.LabelOpts(position="right"))
        #.add_yaxis("商家B", Faker.values(), label_opts=opts.LabelOpts(position="right"))
        .reversal_axis()
        .set_global_opts(
            title_opts=opts.TitleOpts("Timeline-Bar-Reversal (时间: {} 年)".format(i))
        )
    )
    tl.add(bar, "{}年".format(i))
tl.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="84384c3c4d564acd8eb99c082e4ea502" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_84384c3c4d564acd8eb99c082e4ea502 = echarts.init(
#                     document.getElementById('84384c3c4d564acd8eb99c082e4ea502'), 'white', {renderer: 'canvas'});
#                 var option_84384c3c4d564acd8eb99c082e4ea502 = {
#     "baseOption": {
#         "series": [
#             {
#                 "type": "bar",
#                 "name": "\u5546\u5bb6A",
#                 "legendHoverLink": true,
#                 "data": [
#                     90,
#                     87,
#                     65,
#                     137,
#                     21,
#                     115,
#                     85
#                 ],
# ...
